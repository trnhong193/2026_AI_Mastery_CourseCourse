# %% [markdown]
# ### Building a Bot to Answer Questions from a Static Text Passage
# - Create a Static Text Passage
# - Set up LM
# - Create a Func to Answer Questions
# - Test Func
# - Explain of Confidence Score

# %%
from transformers import pipeline
knowledge_base = "'"
